# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

import datetime as dt

import os

# %%
files = [f for f in os.listdir('./data/press_releases/') if 'csv' in f]
files
# Out:
# ['apple_press_releases.csv',
#  'cvs_health_press_releases.csv',
#  'exxon_mobil_press_releases.csv',
#  'walmart_press_releases.csv',
#  'amazon_press_releases.csv']

# %% [markdown]
# ## Finding the dates for each file and assigning the label

# %% [markdown]
# ### Apple

# %%
# find the dates
file = [f for f in files if 'apple' in f]
file
df = pd.read_csv(f'./data/press_releases/{file[0]}')

for row in range(len(df)):
    link_list = [i.strip() for i in df.loc[row,'full_link'].split('/') if i.strip() != '']
    df.loc[row,'time'] = '-'.join(link_list[3:5])

df['full_text'] = df['title'] + df['body']

df.time = df.time.map(lambda x: dt.datetime.strptime(x,'%Y-%m'))
df['year'] = df.time.map(lambda x: x.year)

df

# %%
# assign the label

df['label'] = df.year.map(lambda x: 'after' if x >= 2020 else 'before')

# %%
# save it back

df.to_csv(f'./data/press_releases/{file[0]}', index = False)

# %% [markdown]
# ### CVS Health

# %%
file = [f for f in files if 'cvs' in f]
df = pd.read_csv(f'./data/press_releases/{file[0]}')

years = [str(i) for i in range(2019,2022)]

for row in range(len(df)):
    para_list = [i.strip() for i in df.loc[row,'body'].split('\n') if i.strip() != '']
    df.loc[row,'time'] = '-'.join(para_list[3:6])
    
    for year in years:
        if (year in para_list[324]) & (len(para_list[324])<30):
            df.loc[row,'time'] = ','.join(para_list[324].split(',')[-2:]).strip()
            break
        
        elif (year in para_list[334]) & (len(para_list[334])<30):
            df.loc[row,'time'] = ','.join(para_list[334].split(',')[-2:]).strip()
            break
        
        else:
            df.loc[row,'time'] = None

df = df.dropna().reset_index(drop = True)

df['full_text'] = df.title + df.body

for row in range(len(df)):
    try:
        df.loc[row,'time'] = dt.datetime.strptime(df.loc[row,'time'],'%B %d, %Y')
        df['year'] = df.loc[row,'time'].year
    except:
        print(row)
        
df

# %%
# assign the label

df['label'] = df.year.map(lambda x: 'after' if x >= 2020 else 'before')

# %%
# save it back

df.to_csv(f'./data/press_releases/{file[0]}', index = False)

# %% [markdown]
# ### Exxon Mobil

# %%
file = [f for f in files if 'exxon' in f]
df = pd.read_csv(f'./data/press_releases/{file[0]}')

for row in range(len(df)):

    para_list = [i.strip() for i in df.loc[row,'body'].split('\n') if i.strip() != '']

    for year in years:
        if (year in para_list[87])& (len(para_list[87])<20):
            df.loc[row,'time'] = ','.join(para_list[87].split(',')[-2:]).strip()
            break

        elif (year in para_list[86])& (len(para_list[86])<20):
            df.loc[row,'time'] = ','.join(para_list[86].split(',')[-2:]).strip()
            break
        
        elif (year in para_list[77])& (len(para_list[77])<20):
            df.loc[row,'time'] = ','.join(para_list[77].split(',')[-2:]).strip()
            break
        
        elif (year in para_list[74])& (len(para_list[74])<20):
            df.loc[row,'time'] = ','.join(para_list[74].split(',')[-2:]).strip()
            break
        
        else:
            df.loc[row,'time'] = None

            
df['full_text'] = df.title + df.body


months = {
    'Jan.':'January',
    'Feb.':'February',
    'Mar.':'March',
    'Apr.':'April',
    'Jun.':'June',
    'Jul.':'July',
    'Aug.':'August',
    'Sept.':'September',
    'Oct.':'October',
    'Nov.': 'November',
    'Dec.':'December'
}

for row in range(len(df)):
    for old,new in months.items():
        df.loc[row,'time']=df.loc[row,'time'].replace(old,new).replace('   •','')
            
for row in range(len(df)):
    try:
        df.loc[row,'time'] = dt.datetime.strptime(df.loc[row,'time'],'%B %d, %Y')
        df['year'] = df.loc[row,'time'].year
    except:
        print(row)

df
# Out:
#                                              full_link                 time  \
# 0    https://corporate.exxonmobil.com/News/Newsroom...  2021-03-11 00:00:00
# 1    https://corporate.exxonmobil.com/News/Newsroom...  2021-03-03 00:00:00
# 2    https://corporate.exxonmobil.com/News/Newsroom...  2021-03-02 00:00:00
# 3    https://corporate.exxonmobil.com/News/Newsroom...  2021-03-01 00:00:00
# 4    https://corporate.exxonmobil.com/News/Newsroom...  2021-03-01 00:00:00
# ..                                                 ...                  ...
# 138  https://corporate.exxonmobil.com/News/Newsroom...  2019-01-29 00:00:00
# 139  https://corporate.exxonmobil.com/News/Newsroom...  2019-01-28 00:00:00
# 140  https://corporate.exxonmobil.com/News/Newsroom...  2019-01-23 00:00:00
# 141  https://corporate.exxonmobil.com/News/Newsroom...  2019-01-08 00:00:00
# 142  https://corporate.exxonmobil.com/News/Newsroom...  2019-01-07 00:00:00
#
#                                                  title  \
# 0    Darren Woods shares strategy for long term gro...
# 1    ExxonMobil outlines plans to grow long-term sh...
# 2    ExxonMobil announces Singapore workforce reduc...
# 3    Neil Duffin to retire as president of ExxonMob...
# 4    Michael Angelakis and Jeffrey Ubben join Exxon...
# ..                                                 ...
# 138  ExxonMobil to proceed with new crude unit as p...
# 139  ExxonMobil to release fourth quarter and full ...
# 140  ExxonMobil partners with REG, Clariant to adva...
# 141  ExxonMobil and IBM to advance energy sector ap...
# 142  ExxonMobil Begins Drilling Haimara-1 Explorati...
#
#                                                   body  \
# 0    \n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 1    \n\nSkip to content\n\n\n\nImportant Additiona...
# 2    \n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 3    \n\nSkip to content\n\n\n\nImportant Additiona...
# 4    \n\nSkip to content\n\n\n\nImportant Additiona...
# ..                                                 ...
# 138  \n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 139  \n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 140  \n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 141  \n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142  \n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                                   html  \
# 0    <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 1    <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 2    <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 3    <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 4    <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# ..                                                 ...
# 138  <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 139  <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 140  <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 141  <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
# 142  <!DOCTYPE html>\n<!--[if IE 9]><html lang="en"...
#
#                                              full_text  year
# 0    Darren Woods shares strategy for long term gro...  2019
# 1    ExxonMobil outlines plans to grow long-term sh...  2019
# 2    ExxonMobil announces Singapore workforce reduc...  2019
# 3    Neil Duffin to retire as president of ExxonMob...  2019
# 4    Michael Angelakis and Jeffrey Ubben join Exxon...  2019
# ..                                                 ...   ...
# 138  ExxonMobil to proceed with new crude unit as p...  2019
# 139  ExxonMobil to release fourth quarter and full ...  2019
# 140  ExxonMobil partners with REG, Clariant to adva...  2019
# 141  ExxonMobil and IBM to advance energy sector ap...  2019
# 142  ExxonMobil Begins Drilling Haimara-1 Explorati...  2019
#
# [143 rows x 7 columns]

# %%
# assign the label

df['label'] = df.year.map(lambda x: 'after' if x >= 2020 else 'before')
# Out:
# ['exxon_mobil_press_releases.csv']

# %%
# save it back

df.to_csv(f'./data/press_releases/{file[0]}', index = False)

# %% [markdown]
# ### Walmart

# %%
file = [f for f in files if 'walmart' in f]
df = pd.read_csv(f'./data/press_releases/{file[0]}')

for row in range(len(df)):
    para_list = [i.strip() for i in df.loc[row,'full_link'].split('/') if i.strip() != '']
    df.loc[row,'time'] = '-'.join(para_list[3:6])


df['full_text'] = df.title + df.body

for row in range(len(df)):
    try:
        df.loc[row,'time'] = dt.datetime.strptime(df.loc[row,'time'],'%Y-%m-%d')
        df.loc[row,'year'] = df.loc[row,'time'].year
    except:
        print(row)
        
df
# Out:
#                                              full_link                 time  \
# 0    https://corporate.walmart.com/newsroom/2021/03...  2021-03-09 00:00:00
# 1    https://corporate.walmart.com/newsroom/2021/03...  2021-03-05 00:00:00
# 2    https://corporate.walmart.com/newsroom/2021/03...  2021-03-04 00:00:00
# 3    https://corporate.walmart.com/newsroom/2021/03...  2021-03-04 00:00:00
# 4    https://corporate.walmart.com/newsroom/2021/03...  2021-03-03 00:00:00
# ..                                                 ...                  ...
# 431  https://corporate.walmart.com/newsroom/2019/01...  2019-01-17 00:00:00
# 432  https://corporate.walmart.com/newsroom/2019/01...  2019-01-15 00:00:00
# 433  https://corporate.walmart.com/newsroom/2019/01...  2019-01-14 00:00:00
# 434  https://corporate.walmart.com/newsroom/2019/01...  2019-01-08 00:00:00
# 435  https://corporate.walmart.com/newsroom/2019/01...  2019-01-06 00:00:00
#
#                                                  title  \
# 0    Walmart Doubles Down on TikTok Shopping, Hosts...
# 1    Walmart Board of Directors Adds Former AT&T Ch...
# 2    Walmart Maintains Relentless Focus on Growing ...
# 3    Walmart to Present at Bank of America 2021 Con...
# 4    Investing in the Future of U.S. Manufacturing,...
# ..                                                 ...
# 431  Walmart Expands Its Grocery Delivery Service P...
# 432    Top Ways Walmart is Changing How Customers Shop
# 433  High-Tech Consolidation Center Set to Open in ...
# 434  Custom Autonomous Cargo Vans to Deliver Grocer...
# 435  Introducing Our Biggest Walmart Grocery Pickup...
#
#                                                   body  \
# 0    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 1    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 2    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 3    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 4    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# ..                                                 ...
# 431  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 432  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 433  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 434  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
# 435  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n© 2021 Wal...
#
#                                                   html  \
# 0    <!DOCTYPE html>\n<html class="PressReleasePage...
# 1    <!DOCTYPE html>\n<html class="PressReleasePage...
# 2    <!DOCTYPE html>\n<html class="PressReleasePage...
# 3    <!DOCTYPE html>\n<html class="PressReleasePage...
# 4    <!DOCTYPE html>\n<html class="PressReleasePage...
# ..                                                 ...
# 431  <!DOCTYPE html>\n<html class="PressReleasePage...
# 432  <!DOCTYPE html>\n<html class="PressReleasePage...
# 433  <!DOCTYPE html>\n<html class="PressReleasePage...
# 434  <!DOCTYPE html>\n<html class="PressReleasePage...
# 435  <!DOCTYPE html>\n<html class="PressReleasePage...
#
#                                              full_text    year
# 0    Walmart Doubles Down on TikTok Shopping, Hosts...  2021.0
# 1    Walmart Board of Directors Adds Former AT&T Ch...  2021.0
# 2    Walmart Maintains Relentless Focus on Growing ...  2021.0
# 3    Walmart to Present at Bank of America 2021 Con...  2021.0
# 4    Investing in the Future of U.S. Manufacturing,...  2021.0
# ..                                                 ...     ...
# 431  Walmart Expands Its Grocery Delivery Service P...  2019.0
# 432  Top Ways Walmart is Changing How Customers Sho...  2019.0
# 433  High-Tech Consolidation Center Set to Open in ...  2019.0
# 434  Custom Autonomous Cargo Vans to Deliver Grocer...  2019.0
# 435  Introducing Our Biggest Walmart Grocery Pickup...  2019.0
#
# [436 rows x 7 columns]

# %%
# assign the label

df['label'] = df.year.map(lambda x: 'after' if x >= 2020 else 'before')

# %%
# save it back

df.to_csv(f'./data/press_releases/{file[0]}', index = False)

# %% [markdown]
# ### Amazon

# %%
file = [f for f in files if 'amazon' in f]
df = pd.read_csv(f'./data/press_releases/{file[0]}')

for row in range(len(df)):
    
    if 'BUSINESS WIRE' in df.loc[row,'body']:
        para_list = [i.strip() for i in df.loc[row,'body'].split('\n') if 'BUSINESS WIRE' in i]
        df.loc[row,'time'] = para_list[0].split('--')[-2]
        df.loc[row,'time'] = df.loc[row,'time'].replace('(BUSINESS WIRE)—','').replace('(BUSINESS WIRE)','')
        if len(df.loc[row,'time']) == 0:
            df.loc[row,'time'] = None
    elif 'PRNewswire' in df.loc[row,'body']:
        para_list = [i.strip() for i in df.loc[row,'body'].split('\n') if 'PRNewswire' in i]
        df.loc[row,'time'] = ','.join(para_list[0].split('--')[0].split('/')[0].split(',')[-2:]).strip()
    
    else:
        df.loc[row,'time'] = None

df['full_text'] = df.title + df.body

df = df.dropna().reset_index(drop = True)

for row in range(len(df)):
    try:
        df.loc[row,'time'] = dt.datetime.strptime(df.loc[row,'time'],'%b. %d, %Y')
        df.loc[row,'year'] = df.loc[row,'time'].year
    except:
        df.loc[row,'time'] = dt.datetime.strptime(df.loc[row,'time'],'%B %d, %Y')
        df.loc[row,'year'] = df.loc[row,'time'].year

df
# Out:
#                                              full_link                 time  \
# 0    https://press.aboutamazon.com/news-releases/ne...  2019-12-26 00:00:00
# 1    https://press.aboutamazon.com/news-releases/ne...  2019-12-26 00:00:00
# 2    https://press.aboutamazon.com/news-releases/ne...  2019-12-19 00:00:00
# 3    https://press.aboutamazon.com/news-releases/ne...  2019-12-18 00:00:00
# 4    https://press.aboutamazon.com/news-releases/ne...  2019-12-17 00:00:00
# ..                                                 ...                  ...
# 427  https://press.aboutamazon.com/news-releases/ne...  2021-01-19 00:00:00
# 428  https://press.aboutamazon.com/news-releases/ne...  2021-01-19 00:00:00
# 429  https://press.aboutamazon.com/news-releases/ne...  2021-01-11 00:00:00
# 430  https://press.aboutamazon.com/news-releases/ne...  2021-01-06 00:00:00
# 431  https://press.aboutamazon.com/news-releases/ne...  2021-01-05 00:00:00
#
#                                                  title  \
# 0    Amazon Continues Investment in Florida with De...
# 1    Customers Shopped at Record Levels this Holida...
# 2    Amazon Has Enabled Hundreds of Small Businesse...
# 3    Amazon Makes Returns Even Easier This Holiday ...
# 4    Amazon Helps Keep the Holidays ‘Spoiler Free’ ...
# ..                                                 ...
# 427  Amazon.com to Webcast Fourth Quarter 2020 Fina...
# 428  Amazon Teams Up with Pharrell Williams’ YELLOW...
# 429  Amazon Expands Investment in Metro Detroit, Cr...
# 430  Amazon Launches $2 Billion Housing Equity Fund...
# 431  Amazon Continues to Expand Its Transportation ...
#
#                                                   body  \
# 0    \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 1    \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 2    \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 3    \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 4    \n\n\n\n\n\n\n\n        Skip to main navigatio...
# ..                                                 ...
# 427  \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 428  \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 429  \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 430  \n\n\n\n\n\n\n\n        Skip to main navigatio...
# 431  \n\n\n\n\n\n\n\n        Skip to main navigatio...
#
#                                                   html  \
# 0    <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 1    <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 2    <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 3    <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 4    <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# ..                                                 ...
# 427  <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 428  <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 429  <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 430  <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
# 431  <!DOCTYPE html>\n<html dir="ltr" lang="en" pre...
#
#                                              full_text    year
# 0    Amazon Continues Investment in Florida with De...  2019.0
# 1    Customers Shopped at Record Levels this Holida...  2019.0
# 2    Amazon Has Enabled Hundreds of Small Businesse...  2019.0
# 3    Amazon Makes Returns Even Easier This Holiday ...  2019.0
# 4    Amazon Helps Keep the Holidays ‘Spoiler Free’ ...  2019.0
# ..                                                 ...     ...
# 427  Amazon.com to Webcast Fourth Quarter 2020 Fina...  2021.0
# 428  Amazon Teams Up with Pharrell Williams’ YELLOW...  2021.0
# 429  Amazon Expands Investment in Metro Detroit, Cr...  2021.0
# 430  Amazon Launches $2 Billion Housing Equity Fund...  2021.0
# 431  Amazon Continues to Expand Its Transportation ...  2021.0
#
# [432 rows x 7 columns]

# %%
# assign the label

df['label'] = df.year.map(lambda x: 'after' if x >= 2020 else 'before')

# %%
# save it back

df.to_csv(f'./data/press_releases/{file[0]}', index = False)

# %% [markdown]
# ## Removing potential leak words

# %%
leak_words = [
    '2021', '2020', '2019', 'Covid-19', 'Covid', 'COVID-19', 'COVID',
    'Coronavirus', 'coronavirus', 'pandemic'
]

for file in tqdm(files):
    df = pd.read_csv(f'./data/press_releases/{file}')
    
    for word in leak_words:
        df.full_text = df.full_text.replace(word,'')
    
    df.to_csv(f'./data/press_releases/{file}', index = False)
# Out:
# apple_press_releases.csv
# cvs_health_press_releases.csv
# exxon_mobil_press_releases.csv
# walmart_press_releases.csv
# amazon_press_releases.csv
